# %% [markdown]
# #ASSIGNMENT 1
#
# 1)In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# ANSWER
#
# VALUE- 'hello',-87.8 , 6
#
# EXPRESSION- *,- , / , +
#
# 2)What is the difference between string and variable?
#
# ANSWER
#
# String - It is a data which is stored in a variable
#
# Variable- It is a location to store data in a program
#
# 3)Describe three different data types.
#
# ANSWER
#
# a)Integer -These data types can be zero, positive and negative whole number without the fraction part.The integer type in python is called as str
# b)String - It is a sequence of charecters which is written inside single or double quotes. The string type in python is called as int
# c)float - These data types have a fraction or decimal part.The float type in python is called as float
#
# 4)What is an expression made up of? What do all expressions do?
#
# ANSWER
#
# An expression is a combination of numerical values variables and operators . An expression always returns a value.
#
# 5)This assignment statements, like spam = 10.
# What is the difference between an expression and a statement?
#
# ANSWER
#
# Expression-An expression produces a value.10 is the expression.
#
# Statement- It is an entire line of code that performs an action but never returns a value.spam =10 is the statement
#
# 6)After running the following code, what does the variable bacon contain? bacon = 22 bacon + 1
#
# ANSWER
#
# bacon=22
#
# 7)What should the values of the following two terms be?
#
# ANSWER
#
# 'spam'+'spamspam'  ='spamspamspam'
#
# 'spam'*3 = 'spamspamspam'
#
# 8)Why is eggs a valid variable name while 100 is invalid?
#
# ANSWER
#
# variables can start with lowercase letter, so eggs is valid.
# variables cannot start with digit, so 100 is invalid.
#
#
# 9)What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# ANSWER
#
# a)int()
# b)float()
# c)str()
#
# 10)Why does this expression cause an error? How can you fix it? 'I have eaten'+ 99+ 'burritos'
#
# ANSWER
#
# string and integer concatenation is not possible in python.
#
# This can be fixed by putting '99' in quotes 'I have eaten'+ ' 99 '+ 'burritos'
#
# ​
